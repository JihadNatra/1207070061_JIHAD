# %%
#NAMA : JIHAD NATRA SITUMORANG
#NIM  : 1207070061
#KELAS: TSEB
#=============================================================================================================

#Praktikum PCD 7.3 - Filter Rerata

#Import Library
import matplotlib.pyplot as plt # Mengimpor library matplotlib dengan menggunakan alias plt.
from skimage import data # Mengimpor modul data dari library skimage, yang berisi beberapa gambar sample yang dapat digunakan untuk percobaan.
from skimage.io import imread # Mengimpor fungsi imread dari modul io dalam library skimage, yang digunakan untuk membaca gambar.
from skimage.color import rgb2gray # Mengimpor fungsi rgb2gray dari modul color dalam library skimage, yang digunakan untuk mengkonversi gambar menjadi skala abu-abu.
import numpy as np # Mengimpor library numpy dengan menggunakan alias np.
import cv2 #  Mengimpor library OpenCV dengan menggunakan alias cv2.
#Load & Plot Input Image


citra1 = imread(fname="D:\Belajar Python\Praktikum 7\SourceImage\Jamur.jpg")
citra1 = cv2.cvtColor(citra1,cv2.COLOR_RGB2GRAY)
citra2 = imread(fname="D:\Belajar Python\Praktikum 7\SourceImage\Kocheng.jpg")
citra2 = cv2.cvtColor(citra2,cv2.COLOR_RGB2GRAY)

print('Shape citra 1 : ', citra1.shape)
print('Shape citra 2 : ', citra2.shape)

fig, axes = plt.subplots(1, 2, figsize=(10, 10))
ax = axes.ravel()

ax[0].imshow(citra1, cmap = 'gray')
ax[0].set_title("Citra 1")
ax[1].imshow(citra2, cmap = 'gray')
ax[1].set_title("Citra 2")

#Code Asal Matlab
#=============================================================================================================
#proses filter rerata untuk citra mobil
#F2 = double(inputMobil);
#for baris=2 : tinggiA-1
#    for kolom=2 : lebarA-1
#        jum = F2(baris-1, kolom-1)+ F2(baris-1, kolom) + F2(baris-1, kolom-1) + ...
#              F2(baris, kolom-1) + F2(baris, kolom) + F2(baris, kolom+1) + ...
#              F2(baris+1, kolom-1) + F2(baris+1, kolom) + F2(baris+1, kolom+1);         
#         outputMobil(baris, kolom) = uint8(1/9 * jum);
#    end
#end
#=============================================================================================================

#Menyiapkan variable output
copyCitra1 = citra1.copy().astype(float)
copyCitra2 = citra2.copy().astype(float)

m1,n1 = copyCitra1.shape
output1 = np.empty([m1, n1])

m2,n2 = copyCitra2.shape
output2 = np.empty([m2, n2])
print('Shape copy citra 1 : ', copyCitra1.shape)
print('Shape output citra 1 : ', output1.shape)

print('m1 : ',m1)
print('n1 : ',n1)
print()

print('Shape copy citra 2 : ', copyCitra2.shape)
print('Shape output citra 3 : ', output2.shape)
print('m2 : ',m2)
print('n2 : ',n2)
print()
#Proses Filter Rerata Pada Citra Input 1
for baris in range(0, m1-1):
    for kolom in range(0, n1-1):
        a1 = baris
        b1 = kolom
        jumlah = copyCitra1[a1-1, b1-1] + copyCitra1[a1-1, b1] + copyCitra1[a1-1, b1-1] + \
                 copyCitra1[a1, b1-1] + copyCitra1[a1, b1] + copyCitra1[a1, b1+1] + \
                 copyCitra1[a1+1, b1-1] + copyCitra1[a1+1, b1] + copyCitra1[a1+1, b1+1];  
        output1[a1, b1] = (1/9 * jumlah)

#Proses Filter Rerata Pada Citra Input 2
for baris1 in range(0, m2-1):
    for kolom1 in range(0, n2-1):
        a1 = baris1
        b1 = kolom1
        jumlah = copyCitra2[a1-1, b1-1] + copyCitra2[a1-1, b1] + copyCitra2[a1-1, b1-1] + \
                 copyCitra2[a1, b1-1] + copyCitra2[a1, b1] + copyCitra2[a1, b1+1] + \
                 copyCitra2[a1+1, b1-1] + copyCitra2[a1+1, b1] + copyCitra2[a1+1, b1+1];  
        output2[a1, b1] = (1/9 * jumlah)

#Plot Citra Input dan Output Hasil dari Filter Rerata
fig, axes = plt.subplots(2, 2, figsize=(10, 10))
ax = axes.ravel()

ax[0].imshow(citra1, cmap = 'gray')
ax[0].set_title("Input Citra 1")#memasang judul pada plot

ax[1].imshow(citra2, cmap = 'gray')
ax[1].set_title("Input Citra 1")#memasang judul pada plot

ax[2].imshow(output1, cmap = 'gray')
ax[2].set_title("Output Citra 1")#memasang judul pada plot

ax[3].imshow(output2, cmap = 'gray')
ax[3].set_title("Output Citra 2")#memasang judul pada plot
# Out:
# Shape citra 1 :  (453, 453)
# Shape citra 2 :  (453, 453)
# Shape copy citra 1 :  (453, 453)
# Shape output citra 1 :  (453, 453)
# m1 :  453
# n1 :  453
#
# Shape copy citra 2 :  (453, 453)
# Shape output citra 3 :  (453, 453)
# m2 :  453
# n2 :  453
# Text(0.5, 1.0, 'Output Citra 2')
